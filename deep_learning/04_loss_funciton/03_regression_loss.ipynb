# %% [markdown]
# # 回归问题损失函数

# %%
import torch
import torch.nn as nn
from torch.nn.functional import smooth_l1_loss

# %%
# 定义数据
input = torch.randn(3, 5)
target = torch.randn(3, 5)
print(input)
print(target)
# Out:
# tensor([[-0.0826, -0.9406, -0.9600,  1.0599,  1.2586],
#         [-0.0589,  0.5686,  0.9727, -1.2458, -0.5814],
#         [ 0.5444, -1.9305,  0.5196, -0.1968,  1.1410]])
# tensor([[ 1.3040,  0.8128,  1.5928,  0.1093,  0.6335],
#         [ 1.4874,  0.0818,  0.1424,  0.4437,  0.7501],
#         [-0.8920,  1.2998, -0.4464, -1.1039, -1.2875]])

# %%
# MSE：L2损失函数
mse_loss = nn.MSELoss()
print(mse_loss(input, target))
# Out:
# tensor(2.7270)

# %%
# MAE：L1损失函数
mae_loss = nn.L1Loss()
print(mae_loss(input, target))
# Out:
# tensor(1.4748)

# %%
# Smooth L1
smooth_l1_loss = nn.SmoothL1Loss()
print(smooth_l1_loss(input, target))
# Out:
# tensor(0.9896)
