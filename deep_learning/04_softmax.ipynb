# %%
import torch
import matplotlib.pyplot as plt

# %%
x = torch.randn(3, 5)
print(x)
# Out:
# tensor([[-0.3131, -0.3387, -1.6889, -1.4638, -0.1832],
#         [ 0.2045, -0.3258,  1.1205,  0.6382,  0.5402],
#         [ 0.4810, -0.5680, -2.1675, -1.1686,  1.9699]])

# %%
y = torch.softmax(x, dim=1)
print(y)
# Out:
# tensor([[0.2716, 0.2647, 0.0686, 0.0859, 0.3092],
#         [0.1423, 0.0837, 0.3555, 0.2195, 0.1990],
#         [0.1654, 0.0579, 0.0117, 0.0318, 0.7332]])
