# %%
import torch

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x.detach()
print(x)
print(y)
# Out:
# tensor(2., requires_grad=True)
# tensor(2.)

# %%
# detach() 后对象不一样，但底层数据是共享的
print(id(x))
print(id(y))
print(x.untyped_storage().data_ptr())
print(y.untyped_storage().data_ptr())
# Out:
# 1978282318640
# 1978282320880
# 6259612909696
# 6259612909696

# %%
print(x)
y.zero_()
print(x)
# Out:
# tensor(2., requires_grad=True)
# tensor(0., requires_grad=True)

# %%
# 分别对x、y进行后续计算
z1 = x ** 2
z2 = y ** 2
print(z1)
print(z2)
# Out:
# tensor(0., grad_fn=<PowBackward0>)
# tensor(0.)

# %%
z1.sum().backward()
# z2.sum().backward() # z2没有开启梯度计算，无法进行反向传播

# %%
x = torch.ones(2, 2, requires_grad=True)
y = x * x
print(x)
print(y)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)
# tensor([[1., 1.],
#         [1., 1.]], grad_fn=<MulBackward0>)

# %%
# 分离
u = y.detach()

# %%
# 让u参与新张量的运算
# z = x ^ 3 --> dz/dx = 3 * x ^ 2
# z = u * x --> dz/dx = u   detach()后视为常熟
z = u * x

# %%
# 反向传播，计算所有梯度
z.sum().backward()

# %%
print(x.grad)
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
print(x.grad == u)
# Out:
# tensor([[True, True],
#         [True, True]])

# %% [markdown]
# ## `detach()` vs `data`

# %%
# 用两组数据进行对比
x1 = torch.tensor([1.0, 2, 3], requires_grad=True)
x2 = torch.tensor([1.0, 2, 3], requires_grad=True)
print(x1)
print(x2)
# Out:
# tensor([1., 2., 3.], requires_grad=True)
# tensor([1., 2., 3.], requires_grad=True)

# %%
y1 = x1.sigmoid()
y2 = x2.sigmoid()
print(y1)
print(y2)
# Out:
# tensor([0.7311, 0.8808, 0.9526], grad_fn=<SigmoidBackward0>)
# tensor([0.7311, 0.8808, 0.9526], grad_fn=<SigmoidBackward0>)

# %%
# y1.sum().backward()
# print(x1.grad)
# Out:
# tensor([0.1966, 0.1050, 0.0452])

# %%
# y2.sum().backward()
# print(x2.grad)
# Out:
# tensor([0.1966, 0.1050, 0.0452])

# %%
z1 = y1.data
z2 = y2.detach()
print(z1)
print(z2)  # 目前看来z1和z2完全相同
print(z1.requires_grad)
print(z2.requires_grad)
# Out:
# tensor([0.7311, 0.8808, 0.9526])
# tensor([0.7311, 0.8808, 0.9526])
# False
# False

# %%
z1.zero_()
z2.zero_()
print(y1)
print(y2)
# Out:
# tensor([0., 0., 0.], grad_fn=<SigmoidBackward0>)
# tensor([0., 0., 0.], grad_fn=<SigmoidBackward0>)

# %%
# 对梯度计算的影响
# 使用data，最好只读取，不修改
y1.sum().backward()
print(x1.grad)  # 仍然可以计算，变为0，但是存在问题，只是将数据拿出来一份进行操作，而对原始梯度计算造成了影响

y2.sum().backward()  # 无法计算，直接报错，
print(x2.grad)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 3
#       1 # 对梯度计算的影响
#       2 # 使用data，最好只读取，不修改
# ----> 3 y1.sum().backward()
#       4 print(x1.grad)  # 仍然可以计算，变为0，但是存在问题，只是将数据拿出来一份进行操作，而对原始梯度计算造成了影响
#       6 y2.sum().backward()
#
# File ~\.conda\envs\cuda\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File ~\.conda\envs\cuda\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~\.conda\envs\cuda\Lib\site-packages\torch\autograd\graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# RuntimeError: Trying to backward through the graph a second time (or directly access saved tensors after they have already been freed). Saved intermediate values of the graph are freed when you call .backward() or autograd.grad(). Specify retain_graph=True if you need to backward through the graph a second time or if you need to access saved tensors after calling backward.
